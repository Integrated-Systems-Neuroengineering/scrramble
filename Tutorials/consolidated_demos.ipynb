# %% [markdown]
# # ScRRAMBLe Training Demos
# ---
#
# This script simulates `ScRRAMBLe` architecture on MNIST, CIFAR-10 and CIFAR-100 datasets using the same architecture presented in our manuscript <a href="https://www.nature.com/articles/s44335-026-00071-7">ScRRAMBLe: Block Sparse Deep Learning Architecture for Analog in-Memory Computing Accelerators</a>

# %%
# clone the repo
# !git clone https://github.com/Integrated-Systems-Neuroengineering/scrramble.git

# change directory to scrramble/
# %cd scrramble/

# %%
# install the package in editable mode. 
# pyproject.toml file specifies the dependencies to be installed.
# !pip install -e .

# %%
# enter the Tutorials directory
# %cd Tutorials/

# %% [markdown]
# ## Training ScRRAMBLe on MNIST dataset

# %%
# !python3 scrramble_mnist_training.py --connection_density 0.2 --slot_size 64 --resample 1 --seed 101 --train_steps 30000

# %% [markdown]
# ## Training ScRRAMBLe on CIFAR-10 dataset

# %%
# !python3 scrramblexresnet_cifar10_training.py --connection_density 0.2 --slot_size 16

# %% [markdown]
# ## Training ScRRAMBLe on CIFAR-100 dataset

# %%
# !python3 scrramblexresnet_cifar100_training.py --connection_density 0.75 --slot_size 16 --capsule_sizes 20 10 --train_steps 50000
